# %%
import pandas as pd
import numpy as np
import pylab as pl
from sklearn import neighbors, datasets
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("featv1_ANSI.csv")
dataset.head()
# Out:
#           1         2         3         4         5         6         7  \
# 0  0.000275  0.000203  0.000203  0.000275  0.000336  0.000509  0.000610
# 1  0.000000  0.000000  0.000000  0.000000  0.000010  0.000000  0.000417
# 2  0.000326  0.000224  0.000224  0.000305  0.000539  0.000458  0.000529
# 3  0.002584  0.001577  0.001933  0.003082  0.003723  0.002950  0.002991
# 4  0.000743  0.001475  0.006795  0.014089  0.013397  0.005900  0.002391
#
#           8         9        10  ...         819       820       821  \
# 0  0.000895  0.001149  0.000875  ...    0.007813  0.007125  0.007003
# 1  0.003062  0.005137  0.005035  ...    0.004200  0.003512  0.003417
# 2  0.000427  0.000661  0.000682  ...    0.006389  0.005934  0.005728
# 3  0.002848  0.003103  0.002675  ...    0.009948  0.009983  0.009573
# 4  0.002096  0.001912  0.002126  ...    0.007976  0.007139  0.006607
#
#         822       823       824       825       826       827  class
# 0  0.005815  0.005371  0.004939  0.004250  0.003440  0.066753     c1
# 1  0.002676  0.002348  0.002380  0.001841  0.001111  0.076947     c1
# 2  0.005088  0.004578  0.004144  0.003558  0.002408  0.062309     c1
# 3  0.009854  0.010007  0.010347  0.010253  0.008810  0.128738     c2
# 4  0.006098  0.006132  0.005408  0.005182  0.004197  0.155593     c2
#
# [5 rows x 828 columns]

# %%
data = dataset.iloc[:, 0:827].values
data
# Out:
# array([[  2.74658000e-04,   2.03451000e-04,   2.03451000e-04, ...,
#           4.25045500e-03,   3.44031600e-03,   6.67532290e-02],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.84064700e-03,   1.11073500e-03,   7.69474890e-02],
#        [  3.25521000e-04,   2.23796000e-04,   2.23796000e-04, ...,
#           3.55802400e-03,   2.40817500e-03,   6.23088100e-02],
#        ...,
#        [  1.23087600e-03,   7.22249000e-04,   1.03759800e-03, ...,
#           4.91291700e-03,   4.09409800e-03,   2.86431938e-01],
#        [  4.29280600e-03,   2.63468400e-03,   3.17382800e-03, ...,
#           8.13789900e-03,   7.04737300e-03,   1.84674015e-01],
#        [  3.25520800e-03,   8.03630000e-04,   1.08846000e-03, ...,
#           8.10420400e-03,   6.03704400e-03,   1.08056048e-01]])

# %%
target = dataset.iloc[:,827].values
target
# Out:
# array(['c1', 'c1', 'c1', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2',
#        'c2', 'c2', 'c1', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2',
#        'c2', 'c2', 'c1', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2',
#        'c2', 'c2', 'c1', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2',
#        'c2', 'c2', 'c1', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2',
#        'c2', 'c2', 'c1', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2',
#        'c2', 'c2', 'c1', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2',
#        'c2', 'c2', 'c1', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2',
#        'c2', 'c2', 'c1', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2',
#        'c2', 'c2', 'c1', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2', 'c2',
#        'c2', 'c2', 'c1', 'c1', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3',
#        'c3', 'c3', 'c3', 'c1', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3',
#        'c3', 'c3', 'c3', 'c1', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3',
#        'c3', 'c3', 'c3', 'c1', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3',
#        'c3', 'c3', 'c3', 'c1', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3',
#        'c3', 'c3', 'c3', 'c1', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3',
#        'c3', 'c3', 'c3', 'c1', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3',
#        'c3', 'c3', 'c3', 'c1', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3',
#        'c3', 'c3', 'c3', 'c1', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3',
#        'c3', 'c3', 'c3', 'c1', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3', 'c3',
#        'c3', 'c3', 'c3', 'c1', 'c1', 'c4', 'c4', 'c4', 'c4', 'c4', 'c4',
#        'c4', 'c4', 'c4', 'c4', 'c1', 'c4', 'c4', 'c4', 'c4', 'c4', 'c4',
#        'c4', 'c4', 'c4', 'c4', 'c1', 'c4', 'c4', 'c4', 'c4', 'c4', 'c4',
#        'c4', 'c4', 'c4', 'c4', 'c1', 'c4', 'c4', 'c4', 'c4', 'c4', 'c4',
#        'c4', 'c4', 'c4', 'c4', 'c1', 'c4', 'c4', 'c4', 'c4', 'c4', 'c4',
#        'c4', 'c4', 'c4', 'c4', 'c1', 'c4', 'c4', 'c4', 'c4', 'c4', 'c4',
#        'c4', 'c4', 'c4', 'c4', 'c1', 'c4', 'c4', 'c4', 'c4', 'c4', 'c4',
#        'c4', 'c4', 'c4', 'c4', 'c1', 'c4', 'c4', 'c4', 'c4', 'c4', 'c4',
#        'c4', 'c4', 'c4', 'c4', 'c1', 'c4', 'c4', 'c4', 'c4', 'c4', 'c4',
#        'c4', 'c4', 'c4', 'c4', 'c1', 'c4', 'c4', 'c4', 'c4', 'c4', 'c4',
#        'c4', 'c4', 'c4', 'c4', 'c1', 'c1', 'c5', 'c5', 'c5', 'c5', 'c5',
#        'c5', 'c5', 'c5', 'c5', 'c5', 'c1', 'c5', 'c5', 'c5', 'c5', 'c5',
#        'c5', 'c5', 'c5', 'c5', 'c5', 'c1', 'c5', 'c5', 'c5', 'c5', 'c5',
#        'c5', 'c5', 'c5', 'c5', 'c5', 'c1', 'c5', 'c5', 'c5', 'c5', 'c5',
#        'c5', 'c5', 'c5', 'c5', 'c5', 'c1', 'c5', 'c5', 'c5', 'c5', 'c5',
#        'c5', 'c5', 'c5', 'c5', 'c5', 'c1', 'c5', 'c5', 'c5', 'c5', 'c5',
#        'c5', 'c5', 'c5', 'c5', 'c5', 'c1', 'c5', 'c5', 'c5', 'c5', 'c5',
#        'c5', 'c5', 'c5', 'c5', 'c5', 'c1', 'c5', 'c5', 'c5', 'c5', 'c5',
#        'c5', 'c5', 'c5', 'c5', 'c5', 'c1', 'c5', 'c5', 'c5', 'c5', 'c5',
#        'c5', 'c5', 'c5', 'c5', 'c5', 'c1', 'c5', 'c5', 'c5', 'c5', 'c5',
#        'c5', 'c5', 'c5', 'c5', 'c5', 'c1', 'c1', 'c6', 'c6', 'c6', 'c6',
#        'c6', 'c6', 'c6', 'c6', 'c6', 'c6', 'c1', 'c6', 'c6', 'c6', 'c6',
#        'c6', 'c6', 'c6', 'c6', 'c6', 'c6', 'c1', 'c6', 'c6', 'c6', 'c6',
#        'c6', 'c6', 'c6', 'c6', 'c6', 'c6', 'c1', 'c6', 'c6', 'c6', 'c6',
#        'c6', 'c6', 'c6', 'c6', 'c6', 'c6', 'c1', 'c6', 'c6', 'c6', 'c6',
#        'c6', 'c6', 'c6', 'c6', 'c6', 'c6', 'c1', 'c6', 'c6', 'c6', 'c6',
#        'c6', 'c6', 'c6', 'c6', 'c6', 'c6', 'c1', 'c6', 'c6', 'c6', 'c6',
#        'c6', 'c6', 'c6', 'c6', 'c6', 'c6', 'c1', 'c6', 'c6', 'c6', 'c6',
#        'c6', 'c6', 'c6', 'c6', 'c6', 'c6', 'c1', 'c6', 'c6', 'c6', 'c6',
#        'c6', 'c6', 'c6', 'c6', 'c6', 'c6', 'c1', 'c6', 'c6', 'c6', 'c6',
#        'c6', 'c6', 'c6', 'c6', 'c6', 'c6', 'c1', 'c1', 'c7', 'c7', 'c7',
#        'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c1', 'c7', 'c7', 'c7',
#        'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c1', 'c7', 'c7', 'c7',
#        'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c1', 'c7', 'c7', 'c7',
#        'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c1', 'c7', 'c7', 'c7',
#        'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c1', 'c7', 'c7', 'c7',
#        'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c1', 'c7', 'c7', 'c7',
#        'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c1', 'c7', 'c7', 'c7',
#        'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c1', 'c7', 'c7', 'c7',
#        'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c1', 'c7', 'c7', 'c7',
#        'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c7', 'c1', 'c1', 'c8', 'c8',
#        'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c1', 'c8', 'c8',
#        'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c1', 'c8', 'c8',
#        'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c1', 'c8', 'c8',
#        'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c1', 'c8', 'c8',
#        'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c1', 'c8', 'c8',
#        'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c1', 'c8', 'c8',
#        'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c1', 'c8', 'c8',
#        'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c1', 'c8', 'c8',
#        'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c1', 'c8', 'c8',
#        'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c8', 'c1', 'c1', 'c9',
#        'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c1', 'c9',
#        'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c1', 'c9',
#        'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c1', 'c9',
#        'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c1', 'c9',
#        'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c1', 'c9',
#        'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c1', 'c9',
#        'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c1', 'c9',
#        'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c1', 'c9',
#        'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c1', 'c9',
#        'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c9', 'c1', 'c1',
#        'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10',
#        'c10', 'c1', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10',
#        'c10', 'c10', 'c1', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10',
#        'c10', 'c10', 'c10', 'c1', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10',
#        'c10', 'c10', 'c10', 'c10', 'c1', 'c10', 'c10', 'c10', 'c10', 'c10',
#        'c10', 'c10', 'c10', 'c10', 'c10', 'c1', 'c10', 'c10', 'c10', 'c10',
#        'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c1', 'c10', 'c10', 'c10',
#        'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c1', 'c10', 'c10',
#        'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c1', 'c10',
#        'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c1',
#        'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10', 'c10'], dtype=object)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.33)

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors = 10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %%
knn.score(X_test, y_test)
# Out:
# 0.69393939393939397

# %%
y_predic = knn.predict(X_test)
y_predic
# Out:
# array(['c3', 'c3', 'c9', 'c5', 'c3', 'c8', 'c6', 'c3', 'c3', 'c3', 'c1',
#        'c1', 'c3', 'c3', 'c3', 'c3', 'c3', 'c8', 'c5', 'c3', 'c10', 'c1',
#        'c3', 'c10', 'c9', 'c4', 'c5', 'c7', 'c10', 'c3', 'c8', 'c6', 'c4',
#        'c5', 'c1', 'c1', 'c8', 'c3', 'c1', 'c7', 'c6', 'c7', 'c5', 'c2',
#        'c5', 'c3', 'c1', 'c8', 'c6', 'c3', 'c1', 'c6', 'c1', 'c5', 'c7',
#        'c4', 'c2', 'c3', 'c1', 'c6', 'c1', 'c3', 'c4', 'c8', 'c5', 'c1',
#        'c4', 'c10', 'c6', 'c3', 'c3', 'c5', 'c1', 'c7', 'c5', 'c8', 'c4',
#        'c3', 'c4', 'c2', 'c3', 'c6', 'c2', 'c1', 'c2', 'c1', 'c8', 'c9',
#        'c2', 'c9', 'c5', 'c6', 'c10', 'c3', 'c3', 'c3', 'c2', 'c1', 'c1',
#        'c5', 'c3', 'c1', 'c10', 'c9', 'c4', 'c10', 'c7', 'c4', 'c6', 'c5',
#        'c7', 'c10', 'c4', 'c1', 'c3', 'c4', 'c2', 'c4', 'c5', 'c3', 'c5',
#        'c10', 'c6', 'c6', 'c1', 'c6', 'c6', 'c8', 'c7', 'c3', 'c7', 'c6',
#        'c7', 'c8', 'c6', 'c6', 'c3', 'c7', 'c1', 'c1', 'c10', 'c3', 'c4',
#        'c3', 'c9', 'c9', 'c9', 'c1', 'c1', 'c1', 'c8', 'c8', 'c4', 'c3',
#        'c3', 'c7', 'c1', 'c2', 'c4', 'c6', 'c1', 'c8', 'c9', 'c6', 'c4',
#        'c4', 'c1', 'c6', 'c2', 'c3', 'c1', 'c1', 'c7', 'c1', 'c1', 'c4',
#        'c8', 'c6', 'c4', 'c1', 'c8', 'c6', 'c3', 'c4', 'c4', 'c7', 'c4',
#        'c1', 'c5', 'c3', 'c1', 'c8', 'c6', 'c1', 'c1', 'c8', 'c1', 'c8',
#        'c7', 'c7', 'c3', 'c10', 'c6', 'c7', 'c7', 'c8', 'c5', 'c5', 'c2',
#        'c9', 'c9', 'c4', 'c3', 'c6', 'c9', 'c7', 'c1', 'c5', 'c7', 'c7',
#        'c1', 'c1', 'c3', 'c5', 'c4', 'c10', 'c6', 'c3', 'c3', 'c3', 'c3',
#        'c9', 'c4', 'c4', 'c10', 'c1', 'c1', 'c8', 'c1', 'c9', 'c3', 'c2',
#        'c10', 'c10', 'c1', 'c1', 'c4', 'c5', 'c2', 'c2', 'c5', 'c4', 'c1',
#        'c2', 'c6', 'c4', 'c5', 'c3', 'c2', 'c8', 'c3', 'c5', 'c2', 'c1',
#        'c6', 'c7', 'c10', 'c5', 'c10', 'c1', 'c3', 'c6', 'c8', 'c9', 'c2',
#        'c5', 'c8', 'c5', 'c1', 'c5', 'c10', 'c1', 'c7', 'c7', 'c5', 'c5',
#        'c5', 'c10', 'c8', 'c4', 'c8', 'c1', 'c3', 'c8', 'c10', 'c3', 'c9',
#        'c10', 'c3', 'c4', 'c6', 'c6', 'c4', 'c9', 'c3', 'c2', 'c1', 'c1',
#        'c2', 'c4', 'c10', 'c2', 'c4', 'c3', 'c7', 'c7', 'c6', 'c8', 'c3',
#        'c6', 'c1', 'c4', 'c7', 'c1', 'c7', 'c10', 'c2', 'c7', 'c5', 'c6'], dtype=object)
